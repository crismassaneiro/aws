# %% [markdown]
# ### AWS CLI - GUIA DE INSTALAÇÃO E CADASTRO NO WINDOWS

# %% [markdown]
# -------------------------------------

# %% [markdown]
# ### Passo 1 - Baixe e instale o AWS CLI

# %% [markdown]
# Link: https://docs.aws.amazon.com/cli/latest/userguide/getting-started-install.html
#
# ----------------------------------

# %% [markdown]
# ### Passo 2 - Abra o Prompt de Comando do Windows

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ----------------------------------

# %% [markdown]
# ### Passo 3 - Configure seu perfil CLI

# %% [markdown]
# #### Digite no cmd que você abriu:
# - digite:  aws configure --profile SEU_NOME_AWS (escreva SEU_NOME e coloque _AWS, para você lembrar do que se trata esse nome, mas se quiser escrever qualquer nome, OK : ), é o seu pefil, não é mesmo?)
#
# #### Isso iniciará um assistente interativo que solicitará as seguintes informações:
#
# - AWS Access Key ID: Insira a sua Access Key da AWS. (essa informação é gerada no IAM da sua conta AWS, isso gera um excel com AcCess Key e Secrect Key) OBS: se você perdeu esse excel, precisirá exlcuir as chaves existentes e criar novas, para poder gerar um excel com informações novas. !!Não perca o EXECEL, isso pode dar muita merda se cair em mãos erradas.
#
#     ![image-2.png](attachment:image-2.png) -> depois de digitar, clique ENTER
# - AWS Secret Access Key: Insira a sua Secret Key da AWS. (essa informação é gerada no IAM da sua conta AWS, isso gera um excel com ACcess Key e Secrect Key) OBS: se você perdeu esse excel, precisirá exlcuir as chaves existentes e criar novas, para poder gerar um excel com informações novas. !!Não perca o EXECEL, isso pode dar muita merda se cair em mãos erradas.
#
#     ![image.png](attachment:image.png) -> depois de digitar, clique ENTER
#
# - Default region name: Insira a região AWS padrão que você deseja usar. Por exemplo, "us-east-1" para a região leste dos EUA.
#
#     ![image-3.png](attachment:image-3.png) -> depois de digitar, clique ENTER
# - Default output format: O formato de saída padrão, que normalmente é "json". Você pode aceitar o padrão ou escolher outro formato, se desejar.
#
#     ![image-4.png](attachment:image-4.png) apenas clique ENTER (configurar isso não é necessário, o default será JSON, por isso é só clicar ENTER)
#
#     #### Certifique-se de que as credenciais inseridas estejam corretas e tenham as permissões adequadas para as operações que você planeja realizar com o AWS CLI.
#
#     #### FEITO!!! Você configurou seu PERFIL : )
#
#
#
#     ----------------------------------

# %% [markdown]
# ### PASSO 4 - Descobrindo se o seu perfil está funcionando

# %% [markdown]
# Abra o prompt e escreva: aws s3 ls
#
# Se retornar um lista de buckts da sua conta AWS, significa que sua conexão com a cloud funcionou, caso contrário, você terá de verificar as senhas cadastradas no seu profile AWS
#
# EX:
#
# ![image.png](attachment:image.png)
#
# Se apareceu algo assim:
#
# ![image-2.png](attachment:image-2.png)
#
# é porque você cadastrou seus chaves errado..
#
# ----------------------------------

# %% [markdown]
# ### PASSO 5 - Preciso corrigir o meu profile, porque escrevi alguma informação errada...

# %% [markdown]
# - Abra o cmd e escreva isso aqui: aws configure --profile SEU_NOME_AWS
#
# ![image.png](attachment:image.png)
#
# VERMELHO: valores que foram cadastrados
#
# VERDE: nova valor que você deseja ascrescentar no lugar do antigo
#
# você só precisa escrever os valores corretos novamente, é o mesmo processo do PASSO 3.
# OBS: se você só tiver que alterar uma variável, apenas preencha o campo que precisa ser atualizado e digite ENTER, até finalizar os processo.
# ![image-2.png](attachment:image-2.png)
#
# VERMELHO: valores que foram cadastrados
#
# VERDE: nova valor que você deseja ascrescentar no lugar do antigo
#
# AZUL: fica vazio, pq não precisava atualizar nenhuma
#
# -----------------------

# %% [markdown]
# ### 6 - Como ver quais perfis estão cadastrados na minha máquina

# %% [markdown]
# - Abra o cmd e escreva isso aqui: aws configure list-profiles
#
# EX:
#
# ![image.png](attachment:image.png)
#
# ------------------------------

# %% [markdown]
# 7 - Como excluir um perfil criado ou alterar ele no diretório

# %% [markdown]
# Não existe um comando para exluir, você precisa achar onde o arquivo foi salvo e deletar
# O seu caminho será parecido com esse: C:\Users\Cristian\.aws\config
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
#
# - Aqui você configura seu nome e região
#
# ![image-6.png](attachment:image-6.png)
#
# - Aqui você configura suas chaves, você pode configurar diretamente aqui
#
# ![image-7.png](attachment:image-7.png)
