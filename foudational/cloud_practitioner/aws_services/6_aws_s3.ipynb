# %% [markdown]
# S3 Storage

# %% [markdown]
# Amazon S3 é um dos principais blocos de construção da AWS
#
#     • É anunciado como armazenamento de “escalação infinita”
#     • Muitos sites usam o Amazon S3 como backbone
#     • Muitos serviços da AWS também usam o Amazon S3 como integração
#     • Teremos uma abordagem passo a passo para o S3
#
# Casos de uso do Amazon S3
#
#     • Backup e armazenamento
#     • Recuperação de desastres
#     • Arquivamento • Armazenamento em nuvem híbrida
#     • Hospedagem de aplicativos
#     • Hospedagem de mídia
#     • Data lakes e análise de big data
#     • Entrega de software
#     • Site estático
#
# Amazon S3 – buckets
#
#     • O Amazon S3 permite que as pessoas armazenem objetos (arquivos) em “baldes” (diretórios)
#     • Os buckets devem ter um nome globalmente exclusivo (em todas as regiões e todas as contas)
#     • Os intervalos são definidos no nível da região
#     • O S3 parece um serviço global, mas os buckets são criados em uma região
#     • Convenção de nomes
#     • Sem letras maiúsculas, sem sublinhado
#     • 3 a 63 caracteres
#     • Não é um IP
#     • Deve começar com letra minúscula ou número
#     • NÃO deve começar com o prefixo xn--
#     • NÃO deve terminar com o sufixo -s3alias
#
# Amazon S3 - Objects
#
#     • Objects (files) have a Key
#     • The key is the FULL path:
#     • s3://my-bucket/my_file.txt
#     • s3://my-bucket/my_folder1/another_folder/my_file.txt
#     • The key is composed of prefix + object name
#     • s3://my-bucket/my_folder1/another_folder/my_file.txt
#     • There’s no concept of “directories” within buckets
#     (although the UI will trick you to think otherwise)
#     • Just keys with very long names that contain slashes (“/”)
#
# Amazon S3 – Objetos (cont.)
#
#     • Os valores do objeto são o conteúdo do corpo:
#     • Máx. O tamanho do objeto é 5 TB (5.000 GB)
#     • Se fizer upload de mais de 5 GB, use “multi-part upload”
#     • Metadados (lista de pares de chave/valor de texto – metadados do sistema ou do usuário)
#     • Tags (par chave/valor Unicode – até 10) – úteis para segurança/ciclo de vida
#     • ID da versão (se o versionamento estiver ativado)
#
# Amazon S3 – Security
#
#     • User-Based
#     • IAM Policies – which API calls should be allowed for a specific user from IAM
#     • Resource-Based
#     • Bucket Policies – bucket wide rules from the S3 console - allows cross account
#     • Object Access Control List (ACL) – finer grain (can be disabled)
#     • Bucket Access Control List (ACL) – less common (can be disabled)
#     • Note: an IAM principal can access an S3 object if
#     • The user IAM permissions ALLOW it OR the resource policy ALLOWS it
#     • AND there’s no explicit DENY
#     • Encryption: encrypt objects in Amazon S3 using encryption keys
#
# Políticas de bucket do S3
#
#     • Políticas baseadas em JSON
#     • Recursos: buckets e objetos
#     • Efeito: permitir/negar
#     • Ações: conjunto de API para permitir ou negar
#     • Principal: a conta ou usuário para aplicar o política para
#
#     • Use o bucket S3 para política para:
#
#     • Conceder acesso público ao bucket
#     • Forçar objetos a serem criptografados no upload
#     • Conceder acesso a outra conta (Cross account)
#
#     A gente pode criar um buckt policy com a ajuda da Amazon, basta clicar em policy generator
#
# Detalhes sobre o S3
#
#     Você criou um buckt, entre em properiedades do bucket
#     Fazendo isso, você terá várias opções para personalizar o seu bucket
#     EX: voc~e poderá fazer backup dos arquivos, poderá habilitar o bucket para hostiar um site, coisas desse tipo
#
# Amazon S3 - Replicação (CRR e SRR)
#
#     • Deve habilitar a Versioning (versionamento) nos buckets de origem e destino
#     • Replicação entre Regiões (CRR - Cross-Region Replication)
#     • Replicação na Mesma Região (SRR - Same-Region Replication)
#     • Os buckets podem estar em diferentes contas da AWS
#     • A cópia é assíncrona
#     • Deve fornecer as permissões IAM adequadas ao S3
#     • Casos de uso:
#     • CRR - conformidade, acesso com latência mais baixa, replicação entre contas
#     • SRR - agregação de logs, replicação ao vivo entre produção e teste
#     Para treinar isso, crie 2 buckets, o v1 e v2. Em ambos você habilita o versionamento. Vá no bucket v1, em management - replication rules, ali você cria a regra e seleciona o bucket que receberá a duplicação. Faça o teste com imagens, você verá que tudo que voce coloca no v1, aparecerá no v2...
#
# S3 Storage Classes
#
#     • Amazon S3 Standard - General Purpose
#     • Amazon S3 Standard-Infrequent Access (IA)
#     • Amazon S3 One Zone-Infrequent Access
#     • Amazon S3 Glacier Instant Retrieval
#     • Amazon S3 Glacier Flexible Retrieval
#     • Amazon S3 Glacier Deep Archive
#     • Amazon S3 Intelligent Tiering
#     • Can move between classes manually or using S3 Lifecycle configurations
#
# S3 Durability and Availability
#
#     • Durability:
#     • High durability (99.999999999%, 11 9’s) of objects across multiple AZ
#     • If you store 10,000,000 objects with Amazon S3, you can on average expect to
#
# incur a loss of a single object once every 10,000 years
#
#     • Same for all storage classes
#     • Availability:
#     • Measures how readily available a service is
#     • Varies depending on storage class
#     • Example: S3 standard has 99.99% availability = not available 53 minutes a year
#
# S3 Standard – General Purpose
#
#     • 99.99% Availability
#     • Used for frequently accessed data
#     • Low latency and high throughput
#     • Sustain 2 concurrent facility failures
#     • Use Cases: Big Data analytics, mobile & gaming applications, content
#     distribution…
#
# S3 Storage Classes – Infrequent Access
#
#     • For data that is less frequently accessed, but requires rapid access when needed
#     • Lower cost than S3 Standard
#     • Amazon S3 Standard-Infrequent Access (S3 Standard-IA)
#     • 99.9% Availability
#     • Use cases: Disaster Recovery, backups
#     • Amazon S3 One Zone-Infrequent Access (S3 One Zone-IA)
#     • High durability (99.999999999%) in a single AZ; data lost when AZ is destroyed
#     • 99.5% Availability
#     • Use Cases: Storing secondary backup copies of on-premise data, or data you can recreate
#
# Amazon S3 Glacier Storage Classes
#
#     • Low-cost object storage meant for archiving / backup
#     • Pricing: price for storage + object retrieval cost
#     • Amazon S3 Glacier Instant Retrieval
#     • Millisecond retrieval, great for data accessed once a quarter
#     • Minimum storage duration of 90 days
#     • Amazon S3 Glacier Flexible Retrieval (formerly Amazon S3 Glacier):
#     • Expedited (1 to 5 minutes), Standard (3 to 5 hours), Bulk (5 to 12 hours) – free
#     • Minimum storage duration of 90 days
#     • Amazon S3 Glacier Deep Archive – for long term storage:
#     • Standard (12 hours), Bulk (48 hours)
#     • Minimum storage duration of 180 days
#
# S3 Intelligent-Tiering
#
#     • Small monthly monitoring and auto-tiering fee
#     • Moves objects automatically between Access Tiers based on usage
#     • There are no retrieval charges in S3 Intelligent-Tiering
#     • Frequent Access tier (automatic): default tier
#     • Infrequent Access tier (automatic): objects not accessed for 30 days
#     • Archive Instant Access tier (automatic): objects not accessed for 90 days
#     • Archive Access tier (optional): configurable from 90 days to 700+ days
#     • Deep Archive Access tier (optional): config. from 180 days to 700+ days
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Essas classes de S3 podem ser escolhidas na hora de criar o bucket, bocê também pode pega um arquvo do seu bucket, e escolher qual classe ele será. Você também pode agendare quando o arquivo X irá para outro tipo de S3, use o Lifecycle Rules para fazer isso.
#
#
# S3 Encryption
#
# ![image-3.png](attachment:image-3.png)
#
#     Lembre-se o server side encrypition está sempre ON por padrão...
#
#     IAM Access Analyzer for S3
#
#     É cara que verifica quem está está acessando o bucket X, quem ter as permissões. É o verificador de status de bucket
#
# ![image-4.png](attachment:image-4.png)
#
# Shared Responsability Model for S3
#
#     AWS
#
#     • Infraestrutura (segurança global, durabilidade, disponibilidade, sustentar a perda simultânea • de dados em duas instalações)
#     • Análise de configuração e vulnerabilidades
#     • Validação de conformidade
#
#     Nóis
#
#     • Versionamento do S3
#     • Políticas de Bucket do S3
#     • Configuração de Replicação do S3
#     • Registro e Monitoramento
#     • Classes de Armazenamento do S3
#     • Criptografia de Dados em Repouso e em Trânsito
#
# Data Migrations with AWS Snow Family
#
#     São os meios físicos de tranferir data, nada além disso. Se a coisa ficar séria, eles mandam um caminhão buscar teus dados kkk
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# Família Snow - Processo de Uso
#
#     Solicitar dispositivos Snowball pelo console da AWS para entrega.
#     Instalar o cliente Snowball / AWS OpsHub em seus servidores.
#     Conectar o Snowball aos seus servidores e copiar arquivos usando o cliente.
#     Devolver o dispositivo quando terminar (enviado para a instalação correta da AWS).
#     Os dados serão carregados em um bucket do S3.
#     O Snowball é completamente apagado.
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
# ![image-13.png](attachment:image-13.png)
#
# ![image-14.png](attachment:image-14.png)
#
# Preços do Snowball Edge
#
#     Você paga pelo uso do dispositivo e pela transferência de dados para fora da AWS.
#     A transferência de dados para o Amazon S3 é de $0,00 por GB.
#     Sob Demanda
#     Inclui uma taxa de serviço única por trabalho, que inclui:
#     10 dias de uso para Snowball Edge Storage Optimized 80TB
#     15 dias de uso para Snowball Edge Storage Optimized 210TB
#     Os dias de envio NÃO são contados nos 10 ou 15 dias incluídos.
#     Paga-se por dia por quaisquer dias adicionais.
#     Compromisso Antecipado
#     Pague antecipadamente pelo uso mensal, anual e trienal (Edge Computing).
#     Até 62% de desconto nos preços.
#
# Hybrid Cloud for Storage
#
#     Parte da sua infraestrutura está localizada no local (on-premises).
#     Parte da sua infraestrutura está na nuvem.
#     Isso pode ser devido a:
#     Migrações longas para a nuvem.
#     Requisitos de segurança.
#     Requisitos de conformidade.
#     Estratégia de TI.
#     O S3 é uma tecnologia de armazenamento proprietária (ao contrário de EFS / NFS), então como você expõe os dados do S3 localmente?
#     AWS Storage Gateway!
#
#  ![image-15.png](attachment:image-15.png)
#
#  ![image-16.png](attachment:image-16.png)
#
#  Amazon S3 - Resumo
#
#     Buckets vs. Objects: nome global exclusivo, vinculado a uma região
#     Segurança do S3: política IAM, Política de Bucket do S3 (acesso público), Criptografia do S3
#     Websites do S3: hospedar um site estático no Amazon S3
#     Versionamento do S3: várias versões para arquivos, prevenir exclusões acidentais
#     Replicação do S3: mesma região ou entre regiões, deve habilitar o versionamento
#     Classes de Armazenamento do S3: Padrão, IA, 1Z-IA, Inteligente, Glacier (Instantâneo, Flexível, Profundo)
#     Família Snow: importar dados para o S3 por meio de um dispositivo físico, computação de borda
#     OpsHub: aplicativo de desktop para gerenciar dispositivos da Família Snow
#     Storage Gateway: solução híbrida para estender o armazenamento no local para o S3
