# %% [markdown]
# AWS CLOUD PRACTICTIONER

# %% [markdown]
# What do I think at this point, since I don't have the certification yet? I have a lot of things to learn, so I need practice, making codes during the days, and I have to learn from a reliable source. To do this, I will practice daily through my own projects and I bought two courses from Udemy. The first course offers a complete path to obtain the Practitioner Certification. The second includes five tests about the Practitioner certification. In addition, I will read and practice at the AWS base; they offer a lot of content for free. I think that is a good way to get my first certification. Time will show me

# %% [markdown]
# Useful links
#
# Udemy:
#
# ![image.png](attachment:image.png)
#
# Link: https://www.udemy.com/course/aws-certified-cloud-practitioner-new/

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Link: https://www.udemy.com/course/aws-certified-cloud-practitioner-practice-exams-c/
